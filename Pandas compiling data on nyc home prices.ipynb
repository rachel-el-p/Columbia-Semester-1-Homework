# %% [markdown]
# ## Make a list of all of the filenames you want to open
#
# You _could_ do this manually, but I suggest using my favorite-named tool: **glob**! It works like this:
#
# ```python
# # Get a list of all CSV files in the current directory
# # that start with "sales," e.g. sales-2020.csv, sales-2015.csv, etc
# import glob
# filenames = glob.glob("sales-*.csv")
# ```
#
# * _**Tip:** `*` means "match anything." _It's different than the `.*` we used in class, but it's the same idea._
# * _**Tip:** Make sure your list includes both 2015 *and* 2019. Remember, some are `xls` and some are `xlsx`!

# %%
# !ls
# Out:
# 01 - Data Acquisition.ipynb          2018_brooklyn.xlsx
# 02 - Data Compilation.ipynb          2019_brooklyn.xlsx
# 03 - Data Analysis.ipynb             2020_brooklyn.xlsx
# 04 - Data Exploration.ipynb          2021_brooklyn.xlsx
# 2009_brooklyn.xls                    cleaned.csv
# 2010_brooklyn.xls                    merged.csv
# 2011_brooklyn.xls                    merged_df.csv
# 2012_brooklyn.xls                    nyc_annualized_sales_links_excel.rtf
# 2013_brooklyn.xls                    nyc_annualized_sales_links_excel.txt
# 2014_brooklyn.xls                    sales_2007_brooklyn.xls
# 2015_brooklyn.xls                    sales_2008_brooklyn.xls
# 2016_brooklyn.xls                    urls.txt
# 2017_brooklyn.xls

# %%
import glob

# %%
filenames = glob.glob("*brooklyn.xls*")
filenames
filenames[:5]
# Out:
# ['sales_2007_brooklyn.xls',
#  '2014_brooklyn.xls',
#  '2013_brooklyn.xls',
#  '2012_brooklyn.xls',
#  '2015_brooklyn.xls']

# %% [markdown]
# ## Open one of them with pandas just to test it out. Any of them!
#
# You'll need to use `skiprows=` to skip the first few rows, as they're informational and not actual data.
#
# * _**Tip:** Yes, the column names are awful right now, but you'll fix them later_

# %%
import pandas as pd

df_2021 =pd.read_excel ("2021_brooklyn.xlsx",skiprows= 5)

# %%
df_2021.head()
# Out:
#   Note: Condominium and cooperative sales are on the unit level and understood to have a count of one.  \
# 0                                            BOROUGH
# 1                                                NaN
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#      Unnamed: 1               Unnamed: 2            Unnamed: 3 Unnamed: 4  \
# 0  NEIGHBORHOOD  BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT      BLOCK
# 1           NaN                      NaN                   NaN        NaN
# 2    BATH BEACH  01 ONE FAMILY DWELLINGS                     1       6364
# 3    BATH BEACH  01 ONE FAMILY DWELLINGS                     1       6364
# 4    BATH BEACH  01 ONE FAMILY DWELLINGS                     1       6367
#
#   Unnamed: 5 Unnamed: 6                 Unnamed: 7          Unnamed: 8  \
# 0        LOT  EASE-MENT  BUILDING CLASS AT PRESENT             ADDRESS
# 1        NaN        NaN                        NaN                 NaN
# 2         74        NaN                         A5     72 BAY 14TH ST.
# 3         74        NaN                         A5  72 BAY 14TH STREET
# 4         24        NaN                         A9   8645 BAY 16 STREE
#
#          Unnamed: 9  ...         Unnamed: 11        Unnamed: 12  \
# 0  APARTMENT NUMBER  ...  RESIDENTIAL\nUNITS  COMMERCIAL\nUNITS
# 1               NaN  ...                 NaN                NaN
# 2               NaN  ...                   1                  0
# 3               NaN  ...                   1                  0
# 4               NaN  ...                   1                  0
#
#      Unnamed: 13         Unnamed: 14          Unnamed: 15 Unnamed: 16  \
# 0  TOTAL \nUNITS  LAND \nSQUARE FEET  GROSS \nSQUARE FEET  YEAR BUILT
# 1            NaN                 NaN                  NaN         NaN
# 2              1                2492                  972        1950
# 3              1                2492                  972        1950
# 4              1                1571                 1456        1935
#
#                  Unnamed: 17                      Unnamed: 18 Unnamed: 19  \
# 0  TAX CLASS AT TIME OF SALE  BUILDING CLASS\nAT TIME OF SALE  SALE PRICE
# 1                        NaN                              NaN         NaN
# 2                          1                               A5           0
# 3                          1                               A5      890000
# 4                          1                               A9      925000
#
#            Unnamed: 20
# 0            SALE DATE
# 1                  NaN
# 2  2021-05-21 00:00:00
# 3  2021-10-08 00:00:00
# 4  2021-11-03 00:00:00
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Now open another one.
#
# Keep opening them with the same `.read_excel` options until you find one with bad headers. **UGH!!!** They all have different `skiprows=` values!

# %%
df_2020 =pd.read_excel ("2020_brooklyn.xlsx",skiprows= 5)
df_2020.head()
# Out:
#   Note: Condominium and cooperative sales are on the unit level and understood to have a count of one.  \
# 0                                            BOROUGH
# 1                                                NaN
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#      Unnamed: 1               Unnamed: 2            Unnamed: 3 Unnamed: 4  \
# 0  NEIGHBORHOOD  BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT      BLOCK
# 1           NaN                      NaN                   NaN        NaN
# 2    BATH BEACH  01 ONE FAMILY DWELLINGS                     1       6359
# 3    BATH BEACH  01 ONE FAMILY DWELLINGS                     1       6360
# 4    BATH BEACH  01 ONE FAMILY DWELLINGS                     1       6360
#
#   Unnamed: 5 Unnamed: 6                 Unnamed: 7          Unnamed: 8  \
# 0        LOT  EASE-MENT  BUILDING CLASS AT PRESENT             ADDRESS
# 1        NaN        NaN                        NaN                 NaN
# 2         70        NaN                         S1    8684 15TH AVENUE
# 3         48        NaN                         A5  14 BAY 10TH STREET
# 4         56        NaN                         A5  30 BAY 10TH STREET
#
#          Unnamed: 9  ...         Unnamed: 11        Unnamed: 12  \
# 0  APARTMENT NUMBER  ...  RESIDENTIAL\nUNITS  COMMERCIAL\nUNITS
# 1               NaN  ...                 NaN                NaN
# 2               NaN  ...                   1                  1
# 3               NaN  ...                   1                  0
# 4               NaN  ...                   1                  0
#
#      Unnamed: 13         Unnamed: 14          Unnamed: 15 Unnamed: 16  \
# 0  TOTAL \nUNITS  LAND \nSQUARE FEET  GROSS \nSQUARE FEET  YEAR BUILT
# 1            NaN                 NaN                  NaN         NaN
# 2              2                1933                 4080        1930
# 3              1                2513                 1428        1930
# 4              1                1547                 1428        1930
#
#                  Unnamed: 17                      Unnamed: 18 Unnamed: 19  \
# 0  TAX CLASS AT TIME OF SALE  BUILDING CLASS\nAT TIME OF SALE  SALE PRICE
# 1                        NaN                              NaN         NaN
# 2                          1                               S1     1300000
# 3                          1                               A5      849000
# 4                          1                               A5       75000
#
#            Unnamed: 20
# 0            SALE DATE
# 1                  NaN
# 2  2020-04-28 00:00:00
# 3  2020-03-18 00:00:00
# 4  2020-11-30 00:00:00
#
# [5 rows x 21 columns]

# %%
df_2019=pd.read_excel ("2019_brooklyn.xlsx",skiprows=3)

# %%
df_2019.head()
# Out:
#   Building Class Category is based on Building Class at Time of Sale. Note: Condominium and cooperative sales are on the unit level and understood to have a count of one.  \
# 0                                          BOROUGH\n
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#        Unnamed: 1                 Unnamed: 2  \
# 0  NEIGHBORHOOD\n  BUILDING CLASS CATEGORY\n
# 1      BATH BEACH    01 ONE FAMILY DWELLINGS
# 2      BATH BEACH    01 ONE FAMILY DWELLINGS
# 3      BATH BEACH    01 ONE FAMILY DWELLINGS
# 4      BATH BEACH    01 ONE FAMILY DWELLINGS
#
#                          Unnamed: 3 Unnamed: 4 Unnamed: 5   Unnamed: 6  \
# 0  TAX CLASS AS OF FINAL ROLL 18/19    BLOCK\n      LOT\n  EASE-MENT\n
# 1                                 1       6363         22          NaN
# 2                                 1       6363         48          NaN
# 3                                 1       6363         48          NaN
# 4                                 1       6364         74          NaN
#
#                               Unnamed: 7          Unnamed: 8  \
# 0  BUILDING CLASS AS OF FINAL ROLL 18/19           ADDRESS\n
# 1                                     A9    8645 16TH AVENUE
# 2                                     A9  12 BAY 13TH STREET
# 3                                     A9  12 BAY 13TH STREET
# 4                                     A5  72 BAY 14TH STREET
#
#            Unnamed: 9  ...          Unnamed: 11         Unnamed: 12  \
# 0  APARTMENT NUMBER\n  ...  RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n
# 1                 NaN  ...                    1                   0
# 2                 NaN  ...                    1                   0
# 3                 NaN  ...                    1                   0
# 4                 NaN  ...                    1                   0
#
#      Unnamed: 13         Unnamed: 14          Unnamed: 15   Unnamed: 16  \
# 0  TOTAL UNITS\n  LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n
# 1              1                2058                 1492          1930
# 2              1                3142                 3200          1999
# 3              1                3142                 3200          1999
# 4              1                2492                  972          1950
#
#                    Unnamed: 17                       Unnamed: 18  \
# 0  TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n
# 1                            1                                A9
# 2                            1                                A9
# 3                            1                                A9
# 4                            1                                A5
#
#     Unnamed: 19          Unnamed: 20
# 0  SALE PRICE\n          SALE DATE\n
# 1             0  2019-04-23 00:00:00
# 2             0  2019-02-27 00:00:00
# 3             0  2019-02-11 00:00:00
# 4             0  2019-08-15 00:00:00
#
# [5 rows x 21 columns]

# %%
df_2018 = pd.read_excel ("2018_brooklyn.xlsx")

# %%
df_2018.head()
# Out:
#   BROOKLYN ANNUALIZE SALE FOR 2018.  (All Sales From  January 1, 2018 - December 31, 2018)  \
# 0  Sales File as of 4/11/2019.  Coop Sales Files ...
# 1  Neighborhood Name and Descriptive Data is as o...
# 2  Building Class Category is based on Building C...
# 3                                          BOROUGH\n
# 4                                                  3
#
#        Unnamed: 1                 Unnamed: 2  \
# 0             NaN                        NaN
# 1             NaN                        NaN
# 2             NaN                        NaN
# 3  NEIGHBORHOOD\n  BUILDING CLASS CATEGORY\n
# 4      BATH BEACH    01 ONE FAMILY DWELLINGS
#
#                          Unnamed: 3 Unnamed: 4 Unnamed: 5   Unnamed: 6  \
# 0                               NaN        NaN        NaN          NaN
# 1                               NaN        NaN        NaN          NaN
# 2                               NaN        NaN        NaN          NaN
# 3  TAX CLASS AS OF FINAL ROLL 18/19    BLOCK\n      LOT\n  EASE-MENT\n
# 4                                 1       6360         23          NaN
#
#                               Unnamed: 7        Unnamed: 8  \
# 0                                    NaN               NaN
# 1                                    NaN               NaN
# 2                                    NaN               NaN
# 3  BUILDING CLASS AS OF FINAL ROLL 18/19         ADDRESS\n
# 4                                     A5  8645 15TH AVENUE
#
#            Unnamed: 9  ...          Unnamed: 11         Unnamed: 12  \
# 0                 NaN  ...                  NaN                 NaN
# 1                 NaN  ...                  NaN                 NaN
# 2                 NaN  ...                  NaN                 NaN
# 3  APARTMENT NUMBER\n  ...  RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n
# 4                 NaN  ...                    1                   0
#
#      Unnamed: 13         Unnamed: 14          Unnamed: 15   Unnamed: 16  \
# 0            NaN                 NaN                  NaN           NaN
# 1            NaN                 NaN                  NaN           NaN
# 2            NaN                 NaN                  NaN           NaN
# 3  TOTAL UNITS\n  LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n
# 4              1                1547                 1428          1930
#
#                    Unnamed: 17                       Unnamed: 18  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3  TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n
# 4                            1                                A5
#
#     Unnamed: 19          Unnamed: 20
# 0           NaN                  NaN
# 1           NaN                  NaN
# 2           NaN                  NaN
# 3  SALE PRICE\n          SALE DATE\n
# 4        750000  2018-05-18 00:00:00
#
# [5 rows x 21 columns]

# %%
df_2017 = pd.read_excel ("2017_brooklyn.xls",header=None)
df_2016 = pd.read_excel ("2016_brooklyn.xls",header=None)
df_2015 = pd.read_excel ("2015_brooklyn.xls",header=None)
df_2014 = pd.read_excel ("2014_brooklyn.xls",header=None)
df_2013 = pd.read_excel ("2013_brooklyn.xls",header=None)
df_2012 = pd.read_excel ("2012_brooklyn.xls",header=None)
df_2011 = pd.read_excel ("2011_brooklyn.xls",header=None)
df_2010 = pd.read_excel ("2010_brooklyn.xls",header=None)
df_2009 = pd.read_excel ("2009_brooklyn.xls",header=None)
df_2008 = pd.read_excel ("sales_2008_brooklyn.xls",header=None)
df_2007 = pd.read_excel ("sales_2007_brooklyn.xls",header=None)

# %% [markdown]
# ## Ignoring headers

# %% [markdown]
# We're going to fix this by getting rid of `skiprows=` and using `header=None`. That way NONE of them will have ANY headers.
#
# Try `header=None` on one of them.
#
# (After we combine them all we'll update them with the right header rows.)

# %%
df_2018=pd.read_excel ("2018_brooklyn.xlsx",header=None)

# %%
df_2019 = pd.read_excel ("2019_brooklyn.xlsx",header=None)
df_2020 = pd.read_excel ("2020_brooklyn.xlsx",header=None)
df_2021 = pd.read_excel ("2021_brooklyn.xlsx",header=None)

# %% [markdown]
# ## Open them all at the same time!
#
# Starting from your list of filenames, use a list comprehension (similar to how we did with the Excel sheets) to create a list of dataframes.
#
# You'll probably want to cut and paste your `.read_excel` from above so that none of them come in with headers. We'll add them in later!
#
# * _**Tip:** Make sure you have 15 years of data (aka fifteen years of dataframes)_

# %%
dataframes = [pd.read_excel(filename,header=None) for filename in filenames]
dataframes

#don't know
# Out:
# [                                                      0   \
#  0      Brooklyn All Sales For 2007 (January 2007 - De...
#  1      Neighborhood Name 05/06/12, Descriptive Data i...
#  2      Building Class Category is based on Building C...
#  3                                                BOROUGH
#  4                                                      3
#  ...                                                  ...
#  28642                                                  3
#  28643                                                  3
#  28644                                                  3
#  28645                                                  3
#  28646                                                  3
#
#                                1   \
#  0                            NaN
#  1                            NaN
#  2                            NaN
#  3                   NEIGHBORHOOD
#  4      BATH BEACH
#  ...                          ...
#  28642  WYCKOFF HEIGHTS
#  28643  WYCKOFF HEIGHTS
#  28644  WYCKOFF HEIGHTS
#  28645  WYCKOFF HEIGHTS
#  28646                       3019
#
#                                                   2                     3   \
#  0                                               NaN                   NaN
#  1                                               NaN                   NaN
#  2                                               NaN                   NaN
#  3                           BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT
#  4      01  ONE FAMILY HOMES                                             1
#  ...                                             ...                   ...
#  28642  30  WAREHOUSES                                                   4
#  28643  31  COMMERCIAL VACANT LAND                                      2B
#  28644  31  COMMERCIAL VACANT LAND
#  28645  41  TAX CLASS 4 - OTHER                                          4
#  28646  08  RENTALS - ELEVATOR APARTMENTS
#
#            4    5          6                          7   \
#  0        NaN  NaN        NaN                        NaN
#  1        NaN  NaN        NaN                        NaN
#  2        NaN  NaN        NaN                        NaN
#  3      BLOCK  LOT  EASE-MENT  BUILDING CLASS AT PRESENT
#  4       6361   19                                    A5
#  ...      ...  ...        ...                        ...
#  28642   3199   34                                    E9
#  28643   3259   13                                    C1
#  28644   3328   16
#  28645   3188   30                                    V1
#  28646   1147    7
#
#                                                8                 9   ...  \
#  0                                            NaN               NaN  ...
#  1                                            NaN               NaN  ...
#  2                                            NaN               NaN  ...
#  3                                        ADDRESS  APARTMENT NUMBER  ...
#  4      51 BAY 10TH   STREET                                         ...
#  ...                                          ...               ...  ...
#  28642  40 WYCKOFF AVENUE                                            ...
#  28643  296 STOCKHOLM STREET                                         ...
#  28644  358 GROVE STREET                                             ...
#  28645  386 TROUTMAN STREET                                          ...
#  28646  649 WASHINGTON AVENUE                                        ...
#
#                        11                12           13                14  \
#  0                    NaN               NaN          NaN               NaN
#  1                    NaN               NaN          NaN               NaN
#  2                    NaN               NaN          NaN               NaN
#  3      RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET
#  4                      1                 0            1              1933
#  ...                  ...               ...          ...               ...
#  28642                  0                 1            1              4250
#  28643                  8                 0            8              2500
#  28644                  0                 0            0                 0
#  28645                  0                 0            0              2500
#  28646                  0                 0            0                 0
#
#                        15          16                         17  \
#  0                    NaN         NaN                        NaN
#  1                    NaN         NaN                        NaN
#  2                    NaN         NaN                        NaN
#  3      GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE
#  4                   1660        1930                          1
#  ...                  ...         ...                        ...
#  28642               4250        1931                          4
#  28643               7534        2008                          4
#  28644                  0           0                          4
#  28645                  0           0                          4
#  28646                  0           0                          2
#
#                                     18          19                   20
#  0                                 NaN         NaN                  NaN
#  1                                 NaN         NaN                  NaN
#  2                                 NaN         NaN                  NaN
#  3      BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
#  4                                  A5      649000  2007-08-31 00:00:00
#  ...                               ...         ...                  ...
#  28642                              E9           0  2007-12-17 00:00:00
#  28643                              V1      360000  2007-01-05 00:00:00
#  28644                              V1      301990  2007-12-12 00:00:00
#  28645                              Z9           0  2007-07-13 00:00:00
#  28646                              D1           0  2007-12-12 00:00:00
#
#  [28647 rows x 21 columns],
#                                                        0   \
#  0      BROOKLYN ANNUALIZE SALE FOR 2014.  (All Sales ...
#  1      Sales File as of 3/31/2015.  Coop Sales Files ...
#  2      Neighborhood Name 1/10/15.  Descriptive Data a...
#  3      Building Class Category is based on Building C...
#  4                                              BOROUGH\n
#  ...                                                  ...
#  25361                                                  3
#  25362                                                  3
#  25363                                                  3
#  25364                                                  3
#  25365                                                  3
#
#                                1   \
#  0                            NaN
#  1                            NaN
#  2                            NaN
#  3                            NaN
#  4                 NEIGHBORHOOD\n
#  ...                          ...
#  25361  WYCKOFF HEIGHTS
#  25362  WYCKOFF HEIGHTS
#  25363  WYCKOFF HEIGHTS
#  25364  WYCKOFF HEIGHTS
#  25365  WYCKOFF HEIGHTS
#
#                                                   2                       3   \
#  0                                               NaN                     NaN
#  1                                               NaN                     NaN
#  2                                               NaN                     NaN
#  3                                               NaN                     NaN
#  4                         BUILDING CLASS CATEGORY\n  TAX CLASS AT PRESENT\n
#  ...                                             ...                     ...
#  25361  44  CONDO PARKING                                                  4
#  25362  44  CONDO PARKING                                                  4
#  25363  47  CONDO NON-BUSINESS STORAGE                                     4
#  25364  49  CONDO WAREHOUSES/FACTORY/INDUS                                 4
#  25365  49  CONDO WAREHOUSES/FACTORY/INDUS                                 4
#
#              4      5            6                            7   \
#  0          NaN    NaN          NaN                          NaN
#  1          NaN    NaN          NaN                          NaN
#  2          NaN    NaN          NaN                          NaN
#  3          NaN    NaN          NaN                          NaN
#  4      BLOCK\n  LOT\n  EASE-MENT\n  BUILDING CLASS AT PRESENT\n
#  ...        ...    ...          ...                          ...
#  25361     3328   1089                                        RP
#  25362     3328   1093                                        RP
#  25363     3280   1128                                        RS
#  25364     3238   1008                                        RW
#  25365     3238   1016                                        RW
#
#                                                8                   9   ...  \
#  0                                            NaN                 NaN  ...
#  1                                            NaN                 NaN  ...
#  2                                            NaN                 NaN  ...
#  3                                            NaN                 NaN  ...
#  4                                      ADDRESS\n  APARTMENT NUMBER\n  ...
#  ...                                          ...                 ...  ...
#  25361  358 GROVE STREET                                 P28           ...
#  25362  358 GROVE STREET                                 P32           ...
#  25363  369 HARMAN STREET                                S10           ...
#  25364  101 WYCKOFF AVENUE                               1H            ...
#  25365  101 WYCKOFF AVENUE                               2H            ...
#
#                          11                  12             13  \
#  0                      NaN                 NaN            NaN
#  1                      NaN                 NaN            NaN
#  2                      NaN                 NaN            NaN
#  3                      NaN                 NaN            NaN
#  4      RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n
#  ...                    ...                 ...            ...
#  25361                    0                   0              1
#  25362                    0                   0              1
#  25363                    0                   0              1
#  25364                    0                   0              1
#  25365                    0                   0              1
#
#                         14                   15            16  \
#  0                     NaN                  NaN           NaN
#  1                     NaN                  NaN           NaN
#  2                     NaN                  NaN           NaN
#  3                     NaN                  NaN           NaN
#  4      LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n
#  ...                   ...                  ...           ...
#  25361                   0                    0             0
#  25362                   0                    0             0
#  25363                   0                    0          2009
#  25364                   0                    0             0
#  25365                   0                    0             0
#
#                                  17                                18  \
#  0                              NaN                               NaN
#  1                              NaN                               NaN
#  2                              NaN                               NaN
#  3                              NaN                               NaN
#  4      TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n
#  ...                            ...                               ...
#  25361                            4                                RP
#  25362                            4                                RP
#  25363                            4                                RS
#  25364                            4                                RW
#  25365                            4                                RW
#
#                   19                   20
#  0               NaN                  NaN
#  1               NaN                  NaN
#  2               NaN                  NaN
#  3               NaN                  NaN
#  4      SALE PRICE\n          SALE DATE\n
#  ...             ...                  ...
#  25361             0  2014-12-04 00:00:00
#  25362             0  2014-02-28 00:00:00
#  25363             0  2014-09-10 00:00:00
#  25364        285000  2014-12-19 00:00:00
#  25365        299000  2014-12-10 00:00:00
#
#  [25366 rows x 21 columns],
#                                                        0   \
#  0      BROOKLYN ANNUALIZE SALES FOR 2013.  (All Sales...
#  1      Sales File as of 3/31/2014  Coop Sales Files a...
#  2      Neighborhood Name and Descriptive Data is as o...
#  3      Building Class Category is based on Building C...
#  4                                              BOROUGH\n
#  ...                                                  ...
#  24842                                                  3
#  24843                                                  3
#  24844                                                  3
#  24845                                                  3
#  24846                                                  3
#
#                                1   \
#  0                            NaN
#  1                            NaN
#  2                            NaN
#  3                            NaN
#  4                 NEIGHBORHOOD\n
#  ...                          ...
#  24842  WYCKOFF HEIGHTS
#  24843  WYCKOFF HEIGHTS
#  24844  WYCKOFF HEIGHTS
#  24845  WYCKOFF HEIGHTS
#  24846  WYCKOFF HEIGHTS
#
#                                                   2                       3   \
#  0                                               NaN                     NaN
#  1                                               NaN                     NaN
#  2                                               NaN                     NaN
#  3                                               NaN                     NaN
#  4                         BUILDING CLASS CATEGORY\n  TAX CLASS AT PRESENT\n
#  ...                                             ...                     ...
#  24842  44  CONDO PARKING                                                  4
#  24843  44  CONDO PARKING                                                  4
#  24844  44  CONDO PARKING                                                  4
#  24845  44  CONDO PARKING                                                  4
#  24846  44  CONDO PARKING                                                  4
#
#              4      5            6                            7   \
#  0          NaN    NaN          NaN                          NaN
#  1          NaN    NaN          NaN                          NaN
#  2          NaN    NaN          NaN                          NaN
#  3          NaN    NaN          NaN                          NaN
#  4      BLOCK\n  LOT\n  EASE-MENT\n  BUILDING CLASS AT PRESENT\n
#  ...        ...    ...          ...                          ...
#  24842     3328   1118                                        RP
#  24843     3328   1119                                        RP
#  24844     3328   1121                                        RP
#  24845     3328   1124                                        RP
#  24846     3328   1125                                        RP
#
#                                                8                   9   ...  \
#  0                                            NaN                 NaN  ...
#  1                                            NaN                 NaN  ...
#  2                                            NaN                 NaN  ...
#  3                                            NaN                 NaN  ...
#  4                                      ADDRESS\n  APARTMENT NUMBER\n  ...
#  ...                                          ...                 ...  ...
#  24842  358 GROVE STREET                                 CB5           ...
#  24843  358 GROVE STREET                                 CB6           ...
#  24844  358 GROVE STREET                                 CB8           ...
#  24845  358 GROVE STREET                                 CB11          ...
#  24846  358 GROVE STREET                                 CB12          ...
#
#                          11                  12             13  \
#  0                      NaN                 NaN            NaN
#  1                      NaN                 NaN            NaN
#  2                      NaN                 NaN            NaN
#  3                      NaN                 NaN            NaN
#  4      RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n
#  ...                    ...                 ...            ...
#  24842                    0                   0              1
#  24843                    0                   0              1
#  24844                    0                   0              1
#  24845                    0                   0              1
#  24846                    0                   0              1
#
#                         14                   15            16  \
#  0                     NaN                  NaN           NaN
#  1                     NaN                  NaN           NaN
#  2                     NaN                  NaN           NaN
#  3                     NaN                  NaN           NaN
#  4      LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n
#  ...                   ...                  ...           ...
#  24842                   0                    0             0
#  24843                   0                    0             0
#  24844                   0                    0             0
#  24845                   0                    0             0
#  24846                   0                    0             0
#
#                                  17                                18  \
#  0                              NaN                               NaN
#  1                              NaN                               NaN
#  2                              NaN                               NaN
#  3                              NaN                               NaN
#  4      TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n
#  ...                            ...                               ...
#  24842                            4                                RP
#  24843                            4                                RP
#  24844                            4                                RP
#  24845                            4                                RP
#  24846                            4                                RP
#
#                   19                   20
#  0               NaN                  NaN
#  1               NaN                  NaN
#  2               NaN                  NaN
#  3               NaN                  NaN
#  4      SALE PRICE\n          SALE DATE\n
#  ...             ...                  ...
#  24842             0  2013-12-12 00:00:00
#  24843             0  2013-12-12 00:00:00
#  24844             0  2013-12-12 00:00:00
#  24845             0  2013-12-12 00:00:00
#  24846             0  2013-12-12 00:00:00
#
#  [24847 rows x 21 columns],
#                                                        0   \
#  0      BROOKLYN ANNUALIZE SALE FOR YEAR 2012.  All Sa...
#  1      Sales File as of 03/31/2013  Coop Sales Files ...
#  2      Neighborhood Name and Descriptive Data is as o...
#  3      Building Class Category is based on Building C...
#  4                                              BOROUGH\n
#  ...                                                  ...
#  23492                                                  3
#  23493                                                  3
#  23494                                                  3
#  23495                                                  3
#  23496                                                  3
#
#                                1   \
#  0                            NaN
#  1                            NaN
#  2                            NaN
#  3                            NaN
#  4                 NEIGHBORHOOD\n
#  ...                          ...
#  23492  WYCKOFF HEIGHTS
#  23493  WYCKOFF HEIGHTS
#  23494  WYCKOFF HEIGHTS
#  23495  WYCKOFF HEIGHTS
#  23496  WYCKOFF HEIGHTS
#
#                                                   2                       3   \
#  0                                               NaN                     NaN
#  1                                               NaN                     NaN
#  2                                               NaN                     NaN
#  3                                               NaN                     NaN
#  4                         BUILDING CLASS CATEGORY\n  TAX CLASS AT PRESENT\n
#  ...                                             ...                     ...
#  23492  30  WAREHOUSES                                                     4
#  23493  30  WAREHOUSES                                                     4
#  23494  30  WAREHOUSES                                                     4
#  23495  30  WAREHOUSES                                                     4
#  23496  41  TAX CLASS 4 - OTHER                                            4
#
#              4      5            6                            7   \
#  0          NaN    NaN          NaN                          NaN
#  1          NaN    NaN          NaN                          NaN
#  2          NaN    NaN          NaN                          NaN
#  3          NaN    NaN          NaN                          NaN
#  4      BLOCK\n  LOT\n  EASE-MENT\n  BUILDING CLASS AT PRESENT\n
#  ...        ...    ...          ...                          ...
#  23492     3176     57                                        E1
#  23493     3176    146                                        E9
#  23494     3280     28                                        E1
#  23495     3290     16                                        E9
#  23496     3176     24                                        Z9
#
#                                                8                   9   ...  \
#  0                                            NaN                 NaN  ...
#  1                                            NaN                 NaN  ...
#  2                                            NaN                 NaN  ...
#  3                                            NaN                 NaN  ...
#  4                                      ADDRESS\n  APARTMENT NUMBER\n  ...
#  ...                                          ...                 ...  ...
#  23492  361 TROUTMAN STREET                                            ...
#  23493  383 TROUTMAN STREET                                            ...
#  23494  342 HIMROD STREET                                              ...
#  23495  380 HARMAN STREET                                              ...
#  23496  400 JEFFERSON STREET                                           ...
#
#                          11                  12             13  \
#  0                      NaN                 NaN            NaN
#  1                      NaN                 NaN            NaN
#  2                      NaN                 NaN            NaN
#  3                      NaN                 NaN            NaN
#  4      RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n
#  ...                    ...                 ...            ...
#  23492                    0                   1              1
#  23493                    0                   1              1
#  23494                    0                   1              1
#  23495                    0                   1              1
#  23496                    0                   1              1
#
#                         14                   15            16  \
#  0                     NaN                  NaN           NaN
#  1                     NaN                  NaN           NaN
#  2                     NaN                  NaN           NaN
#  3                     NaN                  NaN           NaN
#  4      LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n
#  ...                   ...                  ...           ...
#  23492                5000                 5000          1950
#  23493                5017                 5000          1972
#  23494                6000                 7140          1931
#  23495                2438                 2975          1931
#  23496               12500                 7500          1931
#
#                                  17                                18  \
#  0                              NaN                               NaN
#  1                              NaN                               NaN
#  2                              NaN                               NaN
#  3                              NaN                               NaN
#  4      TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n
#  ...                            ...                               ...
#  23492                            4                                E1
#  23493                            4                                E9
#  23494                            4                                E1
#  23495                            4                                E9
#  23496                            4                                Z9
#
#                   19                   20
#  0               NaN                  NaN
#  1               NaN                  NaN
#  2               NaN                  NaN
#  3               NaN                  NaN
#  4      SALE PRICE\n          SALE DATE\n
#  ...             ...                  ...
#  23492        622500  2012-07-03 00:00:00
#  23493       1090000  2012-12-28 00:00:00
#  23494             0  2012-12-14 00:00:00
#  23495        400000  2012-04-09 00:00:00
#  23496             0  2012-01-12 00:00:00
#
#  [23497 rows x 21 columns],
#                                                        0   \
#  0      BROOKLYN ANNUALIZE SALE FOR 2015.  (All Sales ...
#  1      Sales File as of 3/31/2016.  Coop Sales Files ...
#  2      Neighborhood Name 4/1/16.  Descriptive Data as...
#  3      Building Class Category is based on Building C...
#  4                                              BOROUGH\n
#  ...                                                  ...
#  25362                                                  3
#  25363                                                  3
#  25364                                                  3
#  25365                                                  3
#  25366                                                  3
#
#                                1   \
#  0                            NaN
#  1                            NaN
#  2                            NaN
#  3                            NaN
#  4                 NEIGHBORHOOD\n
#  ...                          ...
#  25362  WYCKOFF HEIGHTS
#  25363  WYCKOFF HEIGHTS
#  25364  WYCKOFF HEIGHTS
#  25365  WYCKOFF HEIGHTS
#  25366  WYCKOFF HEIGHTS
#
#                                                   2                       3   \
#  0                                               NaN                     NaN
#  1                                               NaN                     NaN
#  2                                               NaN                     NaN
#  3                                               NaN                     NaN
#  4                         BUILDING CLASS CATEGORY\n  TAX CLASS AT PRESENT\n
#  ...                                             ...                     ...
#  25362  44  CONDO PARKING                                                  4
#  25363  44  CONDO PARKING                                                  4
#  25364  44  CONDO PARKING                                                  4
#  25365  44  CONDO PARKING                                                  4
#  25366  44  CONDO PARKING                                                  4
#
#              4      5            6                            7   \
#  0          NaN    NaN          NaN                          NaN
#  1          NaN    NaN          NaN                          NaN
#  2          NaN    NaN          NaN                          NaN
#  3          NaN    NaN          NaN                          NaN
#  4      BLOCK\n  LOT\n  EASE-MENT\n  BUILDING CLASS AT PRESENT\n
#  ...        ...    ...          ...                          ...
#  25362     3310   1013                                        RP
#  25363     3328   1108                                        RP
#  25364     3328   1114                                        RP
#  25365     3328   1115                                        RP
#  25366     3328   1117                                        RP
#
#                                                8                   9   ...  \
#  0                                            NaN                 NaN  ...
#  1                                            NaN                 NaN  ...
#  2                                            NaN                 NaN  ...
#  3                                            NaN                 NaN  ...
#  4                                      ADDRESS\n  APARTMENT NUMBER\n  ...
#  ...                                          ...                 ...  ...
#  25362  330 BLEEKER STREET                               PK5           ...
#  25363  358 GROVE STREET                                 P47           ...
#  25364  358 GROVE STREET                                 CB1           ...
#  25365  358 GROVE STREET                                 CB2           ...
#  25366  358 GROVE STREET                                 CB4           ...
#
#                          11                  12             13  \
#  0                      NaN                 NaN            NaN
#  1                      NaN                 NaN            NaN
#  2                      NaN                 NaN            NaN
#  3                      NaN                 NaN            NaN
#  4      RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n
#  ...                    ...                 ...            ...
#  25362                    0                   0              1
#  25363                    0                   0              1
#  25364                    0                   0              1
#  25365                    0                   0              1
#  25366                    0                   0              1
#
#                         14                   15            16  \
#  0                     NaN                  NaN           NaN
#  1                     NaN                  NaN           NaN
#  2                     NaN                  NaN           NaN
#  3                     NaN                  NaN           NaN
#  4      LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n
#  ...                   ...                  ...           ...
#  25362                   0                    0          2013
#  25363                   0                    0             0
#  25364                   0                    0             0
#  25365                   0                    0             0
#  25366                   0                    0             0
#
#                                  17                                18  \
#  0                              NaN                               NaN
#  1                              NaN                               NaN
#  2                              NaN                               NaN
#  3                              NaN                               NaN
#  4      TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n
#  ...                            ...                               ...
#  25362                            4                                RP
#  25363                            4                                RP
#  25364                            4                                RP
#  25365                            4                                RP
#  25366                            4                                RP
#
#                   19                   20
#  0               NaN                  NaN
#  1               NaN                  NaN
#  2               NaN                  NaN
#  3               NaN                  NaN
#  4      SALE PRICE\n          SALE DATE\n
#  ...             ...                  ...
#  25362             0  2015-06-08 00:00:00
#  25363        560000  2015-05-29 00:00:00
#  25364             0  2015-05-27 00:00:00
#  25365             0  2015-05-27 00:00:00
#  25366        584000  2015-08-14 00:00:00
#
#  [25367 rows x 21 columns],
#                                                        0                1   \
#  0      BROOKLYN ANNUALIZE SALE FOR 2018.  (All Sales ...              NaN
#  1      Sales File as of 4/11/2019.  Coop Sales Files ...              NaN
#  2      Neighborhood Name and Descriptive Data is as o...              NaN
#  3      Building Class Category is based on Building C...              NaN
#  4                                              BOROUGH\n   NEIGHBORHOOD\n
#  ...                                                  ...              ...
#  23665                                                  3  WYCKOFF HEIGHTS
#  23666                                                  3  WYCKOFF HEIGHTS
#  23667                                                  3  WYCKOFF HEIGHTS
#  23668                                                  3  WYCKOFF HEIGHTS
#  23669                                                  3  WYCKOFF HEIGHTS
#
#                                                2   \
#  0                                            NaN
#  1                                            NaN
#  2                                            NaN
#  3                                            NaN
#  4                      BUILDING CLASS CATEGORY\n
#  ...                                          ...
#  23665                             17 CONDO COOPS
#  23666                               27 FACTORIES
#  23667                               27 FACTORIES
#  23668                      29 COMMERCIAL GARAGES
#  23669  42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC
#
#                                       3        4      5            6   \
#  0                                   NaN      NaN    NaN          NaN
#  1                                   NaN      NaN    NaN          NaN
#  2                                   NaN      NaN    NaN          NaN
#  3                                   NaN      NaN    NaN          NaN
#  4      TAX CLASS AS OF FINAL ROLL 18/19  BLOCK\n  LOT\n  EASE-MENT\n
#  ...                                 ...      ...    ...          ...
#  23665                                 2     3270   1002          NaN
#  23666                                 4     3190     45          NaN
#  23667                                 4     3280     49          NaN
#  23668                                 4     3336     10          NaN
#  23669                                 4     3270   1001          NaN
#
#                                            7                    8   \
#  0                                        NaN                  NaN
#  1                                        NaN                  NaN
#  2                                        NaN                  NaN
#  3                                        NaN                  NaN
#  4      BUILDING CLASS AS OF FINAL ROLL 18/19            ADDRESS\n
#  ...                                      ...                  ...
#  23665                                     R9  286 STANHOPE STREET
#  23666                                     F4     309 STARR STREET
#  23667                                     F5    385 HARMAN STREET
#  23668                                     GW    1519 GATES AVENUE
#  23669                                     RA  286 STANHOPE STREET
#
#                         9   ...                   11                  12  \
#  0                     NaN  ...                  NaN                 NaN
#  1                     NaN  ...                  NaN                 NaN
#  2                     NaN  ...                  NaN                 NaN
#  3                     NaN  ...                  NaN                 NaN
#  4      APARTMENT NUMBER\n  ...  RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n
#  ...                   ...  ...                  ...                 ...
#  23665                 NaN  ...                    0                   0
#  23666                 NaN  ...                    0                   1
#  23667                 NaN  ...                    0                   1
#  23668                 NaN  ...                    0                   3
#  23669                   1  ...                    0                   1
#
#                    13                  14                   15            16  \
#  0                NaN                 NaN                  NaN           NaN
#  1                NaN                 NaN                  NaN           NaN
#  2                NaN                 NaN                  NaN           NaN
#  3                NaN                 NaN                  NaN           NaN
#  4      TOTAL UNITS\n  LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n
#  ...              ...                 ...                  ...           ...
#  23665              0                   0                    0             0
#  23666              1               10000                 7125          1967
#  23667              1                2500                 3125          1931
#  23668              3               16600                 6750          1963
#  23669              1                   0                 6616          2009
#
#                                  17                                18  \
#  0                              NaN                               NaN
#  1                              NaN                               NaN
#  2                              NaN                               NaN
#  3                              NaN                               NaN
#  4      TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n
#  ...                            ...                               ...
#  23665                            2                                R9
#  23666                            4                                F4
#  23667                            4                                F5
#  23668                            4                                GW
#  23669                            4                                RA
#
#                   19                   20
#  0               NaN                  NaN
#  1               NaN                  NaN
#  2               NaN                  NaN
#  3               NaN                  NaN
#  4      SALE PRICE\n          SALE DATE\n
#  ...             ...                  ...
#  23665             0  2018-10-18 00:00:00
#  23666       4950000  2018-02-27 00:00:00
#  23667       1480000  2018-04-13 00:00:00
#  23668             0  2018-04-27 00:00:00
#  23669             0  2018-10-18 00:00:00
#
#  [23670 rows x 21 columns],
#                                                        0                1   \
#  0           BROOKLYN ANNUAL SALES FOR CALENDAR YEAR 2021              NaN
#  1      All Sales From January 2021- December 2021. Pr...              NaN
#  2      For sales prior to the Final, Neighborhood Nam...              NaN
#  3      Sales after the Final Roll, Neighborhood Name ...              NaN
#  4      Building Class Category is based on Building C...              NaN
#  ...                                                  ...              ...
#  28968                                                  3  WYCKOFF HEIGHTS
#  28969                                                  3  WYCKOFF HEIGHTS
#  28970                                                  3  WYCKOFF HEIGHTS
#  28971                                                  3  WYCKOFF HEIGHTS
#  28972                                                  3  WYCKOFF HEIGHTS
#
#                                    2    3     4     5    6    7   \
#  0                                NaN  NaN   NaN   NaN  NaN  NaN
#  1                                NaN  NaN   NaN   NaN  NaN  NaN
#  2                                NaN  NaN   NaN   NaN  NaN  NaN
#  3                                NaN  NaN   NaN   NaN  NaN  NaN
#  4                                NaN  NaN   NaN   NaN  NaN  NaN
#  ...                              ...  ...   ...   ...  ...  ...
#  28968               44 CONDO PARKING    4  3290  1420  NaN   RP
#  28969               44 CONDO PARKING    4  3290  1421  NaN   RP
#  28970               44 CONDO PARKING    4  3290  1423  NaN   RG
#  28971               44 CONDO PARKING    4  3310  1012  NaN   RP
#  28972  47 CONDO NON-BUSINESS STORAGE    4  3280  1125  NaN   RS
#
#                               8    9   ...   11   12   13   14   15    16   17  \
#  0                           NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#  1                           NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#  2                           NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#  3                           NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#  4                           NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#  ...                         ...  ...  ...  ...  ...  ...  ...  ...   ...  ...
#  28968    364 HARMAN STREET, PS4  PS4  ...  NaN    1    1  NaN  NaN  2017    4
#  28969    364 HARMAN STREET, PS5  PS5  ...  NaN    1    1  NaN  NaN  2017    4
#  28970    364 HARMAN STREET, PS7  PS7  ...  NaN    1    1  NaN  NaN  2017    4
#  28971  330 BLEECKER STREET, PK4  PK4  ...  NaN    1    1  NaN  NaN  2013    4
#  28972     369 HARMAN STREET, S7   S7  ...  NaN    1    1  NaN  NaN  2009    4
#
#          18      19                   20
#  0      NaN     NaN                  NaN
#  1      NaN     NaN                  NaN
#  2      NaN     NaN                  NaN
#  3      NaN     NaN                  NaN
#  4      NaN     NaN                  NaN
#  ...    ...     ...                  ...
#  28968   RP   15000  2021-02-18 00:00:00
#  28969   RP  600000  2021-02-12 00:00:00
#  28970   RG  575000  2021-05-24 00:00:00
#  28971   RP  875000  2021-10-05 00:00:00
#  28972   RS  629000  2021-04-21 00:00:00
#
#  [28973 rows x 21 columns],
#                                                        0   \
#  0      Brooklyn All Sales For 2009 (January 2009 - De...
#  1      Neighborhood Name 05/06/12, Descriptive Data i...
#  2      Building Class Category is based on Building C...
#  3                                                BOROUGH
#  4                                                      3
#  ...                                                  ...
#  19994                                                  3
#  19995                                                  3
#  19996                                                  3
#  19997                                                  3
#  19998                                                  3
#
#                                1   \
#  0                            NaN
#  1                            NaN
#  2                            NaN
#  3                   NEIGHBORHOOD
#  4      BATH BEACH
#  ...                          ...
#  19994  WYCKOFF HEIGHTS
#  19995  WYCKOFF HEIGHTS
#  19996  WYCKOFF HEIGHTS
#  19997  WYCKOFF HEIGHTS
#  19998  WYCKOFF HEIGHTS
#
#                                                   2                     3   \
#  0                                               NaN                   NaN
#  1                                               NaN                   NaN
#  2                                               NaN                   NaN
#  3                           BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT
#  4      01  ONE FAMILY HOMES                                             1
#  ...                                             ...                   ...
#  19994  30  WAREHOUSES                                                   4
#  19995  30  WAREHOUSES                                                   4
#  19996  30  WAREHOUSES                                                   4
#  19997  30  WAREHOUSES                                                   4
#  19998  41  TAX CLASS 4 - OTHER                                          4
#
#            4    5          6                          7   \
#  0        NaN  NaN        NaN                        NaN
#  1        NaN  NaN        NaN                        NaN
#  2        NaN  NaN        NaN                        NaN
#  3      BLOCK  LOT  EASE-MENT  BUILDING CLASS AT PRESENT
#  4       6360   75                                    A5
#  ...      ...  ...        ...                        ...
#  19994   3200    1                                    E7
#  19995   3210   22                                    E9
#  19996   3210   26                                    E9
#  19997   3345   46                                    E9
#  19998   3210   47                                    Z9
#
#                                                8                 9   ...  \
#  0                                            NaN               NaN  ...
#  1                                            NaN               NaN  ...
#  2                                            NaN               NaN  ...
#  3                                        ADDRESS  APARTMENT NUMBER  ...
#  4      72 BAY 10TH STREET                                           ...
#  ...                                          ...               ...  ...
#  19994  49 WYCKOFF AVENUE                                            ...
#  19995  1282 WILLOUGHBY AVENUE                                       ...
#  19996  1294 WILLOUGHBY AVENUE                                       ...
#  19997  369 PALMETTO STREET                                          ...
#  19998  373 SUYDAM STREET                                            ...
#
#                        11                12           13                14  \
#  0                    NaN               NaN          NaN               NaN
#  1                    NaN               NaN          NaN               NaN
# ...
#  0                    NaN               NaN          NaN               NaN
#  1                    NaN               NaN          NaN               NaN
#  2                    NaN               NaN          NaN               NaN
#  3      RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET
#  4                      1                 1            2              1473
#  ...                  ...               ...          ...               ...
#  19648                  0                 0            0              2500
#  19649                  0                 0            0              2500
#  19650                  0                 2            2             28685
#  19651                  0                 0            0              4000
#  19652                  0                 1            1             10000
#
#                        15          16                         17  \
#  0                    NaN         NaN                        NaN
#  1                    NaN         NaN                        NaN
#  2                    NaN         NaN                        NaN
#  3      GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE
#  4                   1656        1931                          1
#  ...                  ...         ...                        ...
#  19648                  0           0                          4
#  19649                  0           0                          4
#  19650               3600        1931                          4
#  19651                  0           0                          4
#  19652              10000        1911                          4
#
#                                     18          19                   20
#  0                                 NaN         NaN                  NaN
#  1                                 NaN         NaN                  NaN
#  2                                 NaN         NaN                  NaN
#  3      BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
#  4                                  S1      680000  2010-06-30 00:00:00
#  ...                               ...         ...                  ...
#  19648                              G7           0  2010-04-21 00:00:00
#  19649                              G7           0  2010-04-21 00:00:00
#  19650                              G9           0  2010-06-18 00:00:00
#  19651                              G7           0  2010-06-18 00:00:00
#  19652                              E1     1720100  2010-11-12 00:00:00
#
#  [19653 rows x 21 columns],
#                                                        0   \
#  0      Brooklyn Rolling Sales File.  All Sales From J...
#  1      Sales File as of 03/30/2012  Coop Sales Files ...
#  2      Neighborhood Name 04/01/12, Descriptive Data i...
#  3      Building Class Category is based on Building C...
#  4                                                BOROUGH
#  ...                                                  ...
#  20726                                                  3
#  20727                                                  3
#  20728                                                  3
#  20729                                                  3
#  20730                                                  3
#
#                                1   \
#  0                            NaN
#  1                            NaN
#  2                            NaN
#  3                            NaN
#  4                   NEIGHBORHOOD
#  ...                          ...
#  20726  WYCKOFF HEIGHTS
#  20727  WYCKOFF HEIGHTS
#  20728  WYCKOFF HEIGHTS
#  20729  WYCKOFF HEIGHTS
#  20730  WYCKOFF HEIGHTS
#
#                                                   2                     3   \
#  0                                               NaN                   NaN
#  1                                               NaN                   NaN
#  2                                               NaN                   NaN
#  3                                               NaN                   NaN
#  4                           BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT
#  ...                                             ...                   ...
#  20726  28  COMMERCIAL CONDOS                                            4
#  20727  28  COMMERCIAL CONDOS                                            4
#  20728  29  COMMERCIAL GARAGES                                           4
#  20729  29  COMMERCIAL GARAGES                                           4
#  20730  41  TAX CLASS 4 - OTHER                                          4
#
#            4     5          6                          7   \
#  0        NaN   NaN        NaN                        NaN
#  1        NaN   NaN        NaN                        NaN
#  2        NaN   NaN        NaN                        NaN
#  3        NaN   NaN        NaN                        NaN
#  4      BLOCK   LOT  EASE-MENT  BUILDING CLASS AT PRESENT
#  ...      ...   ...        ...                        ...
#  20726   3280  1128                                    R5
#  20727   3280  1129                                    R5
#  20728   3327     1                                    G2
#  20729   3371    20                                    G2
#  20730   3248    53                                    Z9
#
#                                                8                 9   ...  \
#  0                                            NaN               NaN  ...
#  1                                            NaN               NaN  ...
#  2                                            NaN               NaN  ...
#  3                                            NaN               NaN  ...
#  4                                        ADDRESS  APARTMENT NUMBER  ...
#  ...                                          ...               ...  ...
#  20726  369 HARMAN STREET                              S10           ...
#  20727  369 HARMAN STREET                              S11           ...
#  20728  1492 MYRTLE AVENUE                                           ...
#  20729  1400 MADISON STREET                                          ...
#  20730  299 STOCKHOLM STREET                                         ...
#
#                        11                12           13                14  \
#  0                    NaN               NaN          NaN               NaN
#  1                    NaN               NaN          NaN               NaN
#  2                    NaN               NaN          NaN               NaN
#  3                    NaN               NaN          NaN               NaN
#  4      RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET
#  ...                  ...               ...          ...               ...
#  20726                  0                 1            1                 0
#  20727                  0                 1            1                 0
#  20728                  0                 1            1              4790
#  20729                  0                 1            1              1600
#  20730                  0                 1            1              2500
#
#                        15          16                         17  \
#  0                    NaN         NaN                        NaN
#  1                    NaN         NaN                        NaN
#  2                    NaN         NaN                        NaN
#  3                    NaN         NaN                        NaN
#  4      GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE
#  ...                  ...         ...                        ...
#  20726                  0        2009                          4
#  20727                  0        2009                          4
#  20728               2520        1931                          4
#  20729                800        1931                          4
#  20730                155        1931                          4
#
#                                     18          19                   20
#  0                                 NaN         NaN                  NaN
#  1                                 NaN         NaN                  NaN
#  2                                 NaN         NaN                  NaN
#  3                                 NaN         NaN                  NaN
#  4      BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
#  ...                               ...         ...                  ...
#  20726                              R5           0  2011-01-10 00:00:00
#  20727                              R5           0  2011-08-02 00:00:00
#  20728                              G2      450000  2011-10-24 00:00:00
#  20729                              G2      275000  2011-08-10 00:00:00
#  20730                              Z9           0  2011-12-22 00:00:00
#
#  [20731 rows x 21 columns],
#                                                        0   \
#  0      BROOKLYN ANNUALIZE SALE FOR 2016.  (All Sales ...
#  1      Sales File as of 4/1/2017.  Coop Sales Files a...
#  2      Neighborhood Name and Descriptive Data is as o...
#  3      Building Class Category is based on Building C...
#  4                                              BOROUGH\n
#  ...                                                  ...
#  25519                                                  3
#  25520                                                  3
#  25521                                                  3
#  25522                                                  3
#  25523                                                  3
#
#                                1   \
#  0                            NaN
#  1                            NaN
#  2                            NaN
#  3                            NaN
#  4                 NEIGHBORHOOD\n
#  ...                          ...
#  25519  WYCKOFF HEIGHTS
#  25520  WYCKOFF HEIGHTS
#  25521  WYCKOFF HEIGHTS
#  25522  WYCKOFF HEIGHTS
#  25523  WYCKOFF HEIGHTS
#
#                                                   2                       3   \
#  0                                               NaN                     NaN
#  1                                               NaN                     NaN
#  2                                               NaN                     NaN
#  3                                               NaN                     NaN
#  4                         BUILDING CLASS CATEGORY\n  TAX CLASS AT PRESENT\n
#  ...                                             ...                     ...
#  25519  22  STORE BUILDINGS                                                4
#  25520  22  STORE BUILDINGS                                                4
#  25521  27  FACTORIES                                                      4
#  25522  27  FACTORIES                                                      4
#  25523  44  CONDO PARKING                                                  4
#
#              4      5            6                            7   \
#  0          NaN    NaN          NaN                          NaN
#  1          NaN    NaN          NaN                          NaN
#  2          NaN    NaN          NaN                          NaN
#  3          NaN    NaN          NaN                          NaN
#  4      BLOCK\n  LOT\n  EASE-MENT\n  BUILDING CLASS AT PRESENT\n
#  ...        ...    ...          ...                          ...
#  25519     3188     34                                        K4
#  25520     3270     31                                        K4
#  25521     3188     10                                        F4
#  25522     3188     62                                        F4
#  25523     3310   1010                                        RP
#
#                                                8                   9   ...  \
#  0                                            NaN                 NaN  ...
#  1                                            NaN                 NaN  ...
#  2                                            NaN                 NaN  ...
#  3                                            NaN                 NaN  ...
#  4                                      ADDRESS\n  APARTMENT NUMBER\n  ...
#  ...                                          ...                 ...  ...
#  25519  18 WYCKOFF AVENUE                                              ...
#  25520  132 WYCKOFF AVENUE                                             ...
#  25521  348 TROUTMAN STREET                                            ...
#  25522  199 STARR STREET                                               ...
#  25523  330 BLEECKER STREET                              PK2           ...
#
#                          11                  12             13  \
#  0                      NaN                 NaN            NaN
#  1                      NaN                 NaN            NaN
#  2                      NaN                 NaN            NaN
#  3                      NaN                 NaN            NaN
#  4      RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n
#  ...                    ...                 ...            ...
#  25519                    2                   1              3
#  25520                    2                   2              4
#  25521                    0                   1              1
#  25522                    0                   4              4
#  25523                    0                   0              1
#
#                         14                   15            16  \
#  0                     NaN                  NaN           NaN
#  1                     NaN                  NaN           NaN
#  2                     NaN                  NaN           NaN
#  3                     NaN                  NaN           NaN
#  4      LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n
#  ...                   ...                  ...           ...
#  25519                2500                 3971          1931
#  25520                6862                 2000          1910
#  25521                9500                10340          1931
#  25522                8650                10225          1931
#  25523                   0                    0          2013
#
#                                  17                                18  \
#  0                              NaN                               NaN
#  1                              NaN                               NaN
#  2                              NaN                               NaN
#  3                              NaN                               NaN
#  4      TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n
#  ...                            ...                               ...
#  25519                            4                                K4
#  25520                            4                                K4
#  25521                            4                                F4
#  25522                            4                                F4
#  25523                            4                                RP
#
#                   19                   20
#  0               NaN                  NaN
#  1               NaN                  NaN
#  2               NaN                  NaN
#  3               NaN                  NaN
#  4      SALE PRICE\n          SALE DATE\n
#  ...             ...                  ...
#  25519       4300000  2016-05-17 00:00:00
#  25520       4300000  2016-07-13 00:00:00
#  25521             0  2016-03-01 00:00:00
#  25522      10500000  2016-03-01 00:00:00
#  25523             0  2016-01-25 00:00:00
#
#  [25524 rows x 21 columns]]

# %%
dataframes[0]
# Out:
#                                                       0   \
# 0      Brooklyn All Sales For 2007 (January 2007 - De...
# 1      Neighborhood Name 05/06/12, Descriptive Data i...
# 2      Building Class Category is based on Building C...
# 3                                                BOROUGH
# 4                                                      3
# ...                                                  ...
# 28642                                                  3
# 28643                                                  3
# 28644                                                  3
# 28645                                                  3
# 28646                                                  3
#
#                               1   \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                   NEIGHBORHOOD
# 4      BATH BEACH
# ...                          ...
# 28642  WYCKOFF HEIGHTS
# 28643  WYCKOFF HEIGHTS
# 28644  WYCKOFF HEIGHTS
# 28645  WYCKOFF HEIGHTS
# 28646                       3019
#
#                                                  2                     3   \
# 0                                               NaN                   NaN
# 1                                               NaN                   NaN
# 2                                               NaN                   NaN
# 3                           BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT
# 4      01  ONE FAMILY HOMES                                             1
# ...                                             ...                   ...
# 28642  30  WAREHOUSES                                                   4
# 28643  31  COMMERCIAL VACANT LAND                                      2B
# 28644  31  COMMERCIAL VACANT LAND
# 28645  41  TAX CLASS 4 - OTHER                                          4
# 28646  08  RENTALS - ELEVATOR APARTMENTS
#
#           4    5          6                          7   \
# 0        NaN  NaN        NaN                        NaN
# 1        NaN  NaN        NaN                        NaN
# 2        NaN  NaN        NaN                        NaN
# 3      BLOCK  LOT  EASE-MENT  BUILDING CLASS AT PRESENT
# 4       6361   19                                    A5
# ...      ...  ...        ...                        ...
# 28642   3199   34                                    E9
# 28643   3259   13                                    C1
# 28644   3328   16
# 28645   3188   30                                    V1
# 28646   1147    7
#
#                                               8                 9   ...  \
# 0                                            NaN               NaN  ...
# 1                                            NaN               NaN  ...
# 2                                            NaN               NaN  ...
# 3                                        ADDRESS  APARTMENT NUMBER  ...
# 4      51 BAY 10TH   STREET                                         ...
# ...                                          ...               ...  ...
# 28642  40 WYCKOFF AVENUE                                            ...
# 28643  296 STOCKHOLM STREET                                         ...
# 28644  358 GROVE STREET                                             ...
# 28645  386 TROUTMAN STREET                                          ...
# 28646  649 WASHINGTON AVENUE                                        ...
#
#                       11                12           13                14  \
# 0                    NaN               NaN          NaN               NaN
# 1                    NaN               NaN          NaN               NaN
# 2                    NaN               NaN          NaN               NaN
# 3      RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET
# 4                      1                 0            1              1933
# ...                  ...               ...          ...               ...
# 28642                  0                 1            1              4250
# 28643                  8                 0            8              2500
# 28644                  0                 0            0                 0
# 28645                  0                 0            0              2500
# 28646                  0                 0            0                 0
#
#                       15          16                         17  \
# 0                    NaN         NaN                        NaN
# 1                    NaN         NaN                        NaN
# 2                    NaN         NaN                        NaN
# 3      GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE
# 4                   1660        1930                          1
# ...                  ...         ...                        ...
# 28642               4250        1931                          4
# 28643               7534        2008                          4
# 28644                  0           0                          4
# 28645                  0           0                          4
# 28646                  0           0                          2
#
#                                    18          19                   20
# 0                                 NaN         NaN                  NaN
# 1                                 NaN         NaN                  NaN
# 2                                 NaN         NaN                  NaN
# 3      BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 4                                  A5      649000  2007-08-31 00:00:00
# ...                               ...         ...                  ...
# 28642                              E9           0  2007-12-17 00:00:00
# 28643                              V1      360000  2007-01-05 00:00:00
# 28644                              V1      301990  2007-12-12 00:00:00
# 28645                              Z9           0  2007-07-13 00:00:00
# 28646                              D1           0  2007-12-12 00:00:00
#
# [28647 rows x 21 columns]

# %% [markdown]
# ## Combine them with `pd.concat`
#
# Confirm that you should have 35,8054 rows and 21 columns. If your numbers are a *little* off you probably didn't ignore headers! (In which case, go back and do that.)
#
# Your headers should just be numbers - 0, 1, 2, 3, 4.... etc.
#
# * _**Tip:** Be sure to `ignore_index=True`_

# %%
#to combine a bunch of dataframes, you use pd.concat
#pd.concat([df1, df2, df3, df4), ignore_index=True])

# %%
df = pd.concat([df_2021,df_2020,df_2019,df_2018,df_2017,df_2016, \
            df_2015,df_2014,df_2013,df_2012,df_2011,df_2010,df_2009,df_2008,df_2007], ignore_index=True)
df.shape
# Out:
# (358054, 21)

# %%
df = pd.concat(dataframes,ignore_index=True)
df.shape
# Out:
# (358054, 21)

# %% [markdown]
# ## Add in the headers
#
# The fourth row seems to be the headers. You can update the headers to be the info from the 4rd row.
#
# ```python
# df.columns = df.loc[3].tolist()
# ```

# %%
df.columns = df.loc[3].tolist()
df.head()
# Out:
#                                              BOROUGH  \
# 0  Brooklyn All Sales For 2007 (January 2007 - De...
# 1  Neighborhood Name 05/06/12, Descriptive Data i...
# 2  Building Class Category is based on Building C...
# 3                                            BOROUGH
# 4                                                  3
#
#                 NEIGHBORHOOD                       BUILDING CLASS CATEGORY  \
# 0                        NaN                                           NaN
# 1                        NaN                                           NaN
# 2                        NaN                                           NaN
# 3               NEIGHBORHOOD                       BUILDING CLASS CATEGORY
# 4  BATH BEACH                 01  ONE FAMILY HOMES
#
#    TAX CLASS AT PRESENT  BLOCK  LOT  EASE-MENT  BUILDING CLASS AT PRESENT  \
# 0                   NaN    NaN  NaN        NaN                        NaN
# 1                   NaN    NaN  NaN        NaN                        NaN
# 2                   NaN    NaN  NaN        NaN                        NaN
# 3  TAX CLASS AT PRESENT  BLOCK  LOT  EASE-MENT  BUILDING CLASS AT PRESENT
# 4                     1   6361   19                                    A5
#
#                                      ADDRESS  APARTMENT NUMBER  ...  \
# 0                                        NaN               NaN  ...
# 1                                        NaN               NaN  ...
# 2                                        NaN               NaN  ...
# 3                                    ADDRESS  APARTMENT NUMBER  ...
# 4  51 BAY 10TH   STREET                                         ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                NaN               NaN          NaN               NaN
# 1                NaN               NaN          NaN               NaN
# 2                NaN               NaN          NaN               NaN
# 3  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET
# 4                  1                 0            1              1933
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0                NaN         NaN                        NaN
# 1                NaN         NaN                        NaN
# 2                NaN         NaN                        NaN
# 3  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE
# 4               1660        1930                          1
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 0                             NaN         NaN                  NaN
# 1                             NaN         NaN                  NaN
# 2                             NaN         NaN                  NaN
# 3  BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 4                              A5      649000  2007-08-31 00:00:00
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Remove the notation rows from the top of the Excel sheets
#
# We used `dropna` in class on Monday to remove rows that were missing a `Treatment Date`. Let's do the same thing here to help remove some of the garbage - it seems like we can probably rely on `NEIGHBORHOOD` or `BLOCK` missing to mean that it's a garbage row.

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")
df.head(1)
# Out:
#                                              borough neighborhood  \
# 0  Brooklyn All Sales For 2007 (January 2007 - De...          NaN
#
#   building_class_category tax_class_at_present block  lot ease-ment  \
# 0                     NaN                  NaN   NaN  NaN       NaN
#
#   building_class_at_present address apartment_number  ... residential_units  \
# 0                       NaN     NaN              NaN  ...               NaN
#
#   commercial_units total_units land_square_feet gross_square_feet year_built  \
# 0              NaN         NaN              NaN               NaN        NaN
#
#   tax_class_at_time_of_sale building_class_at_time_of_sale sale_price  \
# 0                       NaN                            NaN        NaN
#
#   sale_date
# 0       NaN
#
# [1 rows x 21 columns]

# %%
#We want to get rid of every single row that is missing a treatment date
print("Before dropping", df.shape)
df=df.dropna(subset=['neighborhood'])
df=df.dropna(subset=['block']) 
print("After dropping", df.shape)
# Out:
# Before dropping (358054, 21)
# After dropping (357992, 21)

# %% [markdown]
# Confirm that you have **357992** rows remaining.

# %% [markdown]
# ## Clean up the data, then remove the duplicated header rows
#
# Every Excel sheet brought in a new 'BOROUGH' and 'NEIGHBORHOOD', etc, that were supposed to be headers.
#
# Let's look at `df.BOROUGH`. Do a `value_counts()` to see whether you notice anything unexpected.

# %%
df.borough.value_counts()
# Out:
# 3            285837
# 3             72140
# BOROUGH\n         8
# BOROUGH           7
# Name: borough, dtype: int64

# %% [markdown]
# Looks like there's all sorts of spaces or newlines – instead of `3` sometimes it's `3 ` (and probably other garbage like that). In theory we could get rid of it easily using `.str.strip()`, which removes whitespace from before/after a string.
#
# ```python
# df.BOROUGH = df.BOROUGH.str.strip()
# ```
#
# The problem is this is probably a problem in *all of the columns*. [This StackOverflow answer sets you up with a pretty good option,](https://stackoverflow.com/a/45270483) but it doesn't work in some edge cases. And of course our dataset is one of them! So try this out:
#
# ```python
# df = df.apply(lambda col: col.astype(str).str.strip())
# ```
#
# `.apply` is like a for loop for pandas - this loops through every column and runs `.str.strip()` on it.

# %%
df = df.apply(lambda col: col.astype(str).str.strip())
df.borough.value_counts()
# Out:
# 3          357977
# BOROUGH        15
# Name: borough, dtype: int64

# %% [markdown]
# Try your `value_counts()` again and let's see if it worked! It should look something like this:
#
# ```
# 3          72140
# BOROUGH       15
# Name: BOROUGH, dtype: int64
# ```

# %%
#why is my result different?df1 = df.loc[df["Discount"] >=1500 ]

# %% [markdown]
# *Now* we can finally remove all of the rows where the column `df.BOROUGH` is the string `"BOROUGH"`.

# %%
#how do we drop rows. 
#df = df.loc[df["borough"] == 3]

df[df["borough"] == 3].borough.value_counts()
# Out:
# Series([], Name: borough, dtype: int64)

# %% [markdown]
# Confirm you now have **357,977 rows**.

# %% [markdown]
# ## Save the cleaned file
#
# It's good practice to save your cleaned data before you start your analysis. Use `.to_csv` to save the cleaned data, passing `index=False` so it doesn't save the index.

# %%
df.to_csv('nychousingdata.csv', index=False)
